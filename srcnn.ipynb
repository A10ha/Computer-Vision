# %%
import cv2
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from keras.models import load_model
from sklearn.model_selection import train_test_split

from keras.layers import Input, Conv2D, MaxPooling2D, UpSampling2D, Add
from keras.models import Model
import keras.backend as K
from keras.optimizers import Adam
from keras.callbacks import LearningRateScheduler, ModelCheckpoint

# %matplotlib inline

# %%
def load_images(inputdir, inputpath, imagesize):
    imglist = []
    
    for i in range(len(inputpath)):
        img = cv2.imread(inputdir+inputpath[i], cv2.IMREAD_COLOR) 
        img=cv2.resize(img,(128,128))
        img = img[::-1] 
        imglist.append(img)
        
    return imglist

# %%
IMAGE_SIZE = 128


image_path = sorted(os.listdir("/home/sd/zsq_python/T91/"))


image =load_images("/home/sd/zsq_python/T91/", image_path, IMAGE_SIZE)
 
image /= np.max(image)

image.shape
# Out:
# (91, 128, 128, 3)

# %%
label= np.zeros((91,128,128,3), np.float32)
for i in range(image.shape[0]):
    temp=cv2.resize(image[i,:,:,:],(64,64))
    temp=cv2.resize(temp,(128,128))
    label[i,:,:,:]=temp
label.shape
# Out:
# (91, 128, 128, 3)

# %%
plt.imshow(label[0])

# %%
plt.imshow(image[0])

# %%
num = 20

plt.figure(figsize=(14, 7))

ax = plt.subplot(1, 2, 1)
plt.imshow(np.squeeze(image[num]))

ax = plt.subplot(1, 2, 2)
plt.imshow(np.squeeze(label[num]))

# %%
def network_srcnn():
    input_img = Input(shape=(IMAGE_SIZE,IMAGE_SIZE,3))
    
    enc1 = Conv2D(64,kernel_size=3,activation="relu",padding="same")(input_img)
    enc1 = Conv2D(64,kernel_size=3,activation="relu",padding="same")(enc1)
    down1 = MaxPooling2D(pool_size=2)(enc1)

    enc2 = Conv2D(128,kernel_size=3,activation="relu",padding="same")(down1)
    enc2 = Conv2D(128,kernel_size=3,activation="relu",padding="same")(enc2)
    down2 = MaxPooling2D(pool_size=2)(enc2)
    
    enc3 = Conv2D(256,kernel_size=3,activation="relu",padding="same")(down2)
    
    up3 = UpSampling2D(size=2)(enc3)
    dec3 = Conv2D(128,kernel_size=3,activation="relu",padding="same")(up3)
    dec3 = Conv2D(128,kernel_size=3,activation="relu",padding="same")(dec3)
    
    add2 = Add()([dec3,enc2])
    up2 = UpSampling2D(size=2)(add2)
    dec2 = Conv2D(64,kernel_size=3,activation="relu",padding="same")(up2)
    dec2 = Conv2D(64,kernel_size=3,activation="relu",padding="same")(dec2)
    
    add1 = Add()([dec2,enc1])
    dec1 = Conv2D(3,kernel_size=5,activation="linear",padding="same")(add1)
    
    model = Model(input_img,dec1)
    return model

model = network_srcnn()
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 128, 128, 3) 0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 128, 128, 64) 1792        input_1[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 128, 128, 64) 36928       conv2d[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 64, 64, 64)   0           conv2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 64, 64, 128)  73856       max_pooling2d[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 64, 64, 128)  147584      conv2d_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 32, 32, 128)  0           conv2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 32, 32, 256)  295168      max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# up_sampling2d (UpSampling2D)    (None, 64, 64, 256)  0           conv2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 64, 64, 128)  295040      up_sampling2d[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 64, 64, 128)  147584      conv2d_5[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 64, 64, 128)  0           conv2d_6[0][0]
#                                                                  conv2d_3[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_1 (UpSampling2D)  (None, 128, 128, 128 0           add[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 128, 128, 64) 73792       up_sampling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 128, 128, 64) 36928       conv2d_7[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 128, 128, 64) 0           conv2d_8[0][0]
#                                                                  conv2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 128, 128, 3)  4803        add_1[0][0]
# ==================================================================================================
# Total params: 1,113,475
# Trainable params: 1,113,475
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# train

# %%
initial_learningrate=2e-3
    
def lr_decay(epoch):
    if epoch < 500:
        return initial_learningrate
    else:
        return initial_learningrate * 0.99 ** epoch


def psnr(y_true,y_pred):
    return -10*K.log(K.mean(K.flatten((y_true-y_pred))**2))/np.log(10)

model.compile(loss="mean_squared_error",optimizer=Adam(lr=initial_learningrate),metrics=[psnr])
model.fit(label,image,epochs=200,batch_size=32,verbose=1,callbacks=[LearningRateScheduler(lr_decay,verbose=1)])
# Out:
# /home/sd/.local/lib/python3.8/site-packages/tensorflow/python/keras/optimizer_v2/optimizer_v2.py:374: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   warnings.warn(
# Epoch 1/200
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.002.
# 3/3 [==============================] - 54s 10s/step - loss: 0.9785 - psnr: 3.2274
# Epoch 2/200
#
# Epoch 00002: LearningRateScheduler reducing learning rate to 0.002.
# 3/3 [==============================] - 33s 11s/step - loss: 0.2285 - psnr: 6.4225
# Epoch 3/200
#
# Epoch 00003: LearningRateScheduler reducing learning rate to 0.002.
# 3/3 [==============================] - 33s 11s/step - loss: 0.2030 - psnr: 7.1551
# Epoch 4/200
#
# Epoch 00004: LearningRateScheduler reducing learning rate to 0.002.
# 3/3 [==============================] - 33s 11s/step - loss: 0.1989 - psnr: 8.0180
# Epoch 5/200
#
# Epoch 00005: LearningRateScheduler reducing learning rate to 0.002.
# 3/3 [==============================] - 32s 11s/step - loss: 0.1588 - psnr: 8.0005
# Epoch 6/200
#
# Epoch 00006: LearningRateScheduler reducing learning rate to 0.002.
# 3/3 [==============================] - 33s 11s/step - loss: 0.1254 - psnr: 9.3331
# Epoch 7/200
#
# Epoch 00007: LearningRateScheduler reducing learning rate to 0.002.
# 3/3 [==============================] - 32s 11s/step - loss: 0.0720 - psnr: 11.5111
# Epoch 8/200
#
# Epoch 00008: LearningRateScheduler reducing learning rate to 0.002.
# 3/3 [==============================] - 33s 11s/step - loss: 0.0392 - psnr: 14.0828
# Epoch 9/200
#
# Epoch 00009: LearningRateScheduler reducing learning rate to 0.002.
# 3/3 [==============================] - 32s 11s/step - loss: 0.0377 - psnr: 14.2427
# Epoch 10/200
#
# Epoch 00010: LearningRateScheduler reducing learning rate to 0.002.
# 3/3 [==============================] - 33s 11s/step - loss: 0.0348 - psnr: 14.5925
# Epoch 11/200
#
# Epoch 00011: LearningRateScheduler reducing learning rate to 0.002.
# 3/3 [==============================] - 33s 11s/step - loss: 0.0302 - psnr: 15.2247
# Epoch 12/200
#
# Epoch 00012: LearningRateScheduler reducing learning rate to 0.002.
# 3/3 [==============================] - 33s 11s/step - loss: 0.0230 - psnr: 16.3830
# Epoch 13/200
#
# Epoch 00013: LearningRateScheduler reducing learning rate to 0.002.
# 3/3 [==============================] - 33s 11s/step - loss: 0.0221 - psnr: 16.5794
# Epoch 14/200
#
# Epoch 00014: LearningRateScheduler reducing learning rate to 0.002.
# 3/3 [==============================] - 33s 11s/step - loss: 0.0190 - psnr: 17.2256
# Epoch 15/200
#
# Epoch 00015: LearningRateScheduler reducing learning rate to 0.002.
# 3/3 [==============================] - 33s 11s/step - loss: 0.0173 - psnr: 17.6299
# Epoch 16/200
#
# Epoch 00016: LearningRateScheduler reducing learning rate to 0.002.
# 3/3 [==============================] - 33s 11s/step - loss: 0.0156 - psnr: 18.0872
# Epoch 17/200
#
# Epoch 00017: LearningRateScheduler reducing learning rate to 0.002.
# 3/3 [==============================] - 33s 11s/step - loss: 0.0145 - psnr: 18.3784
# Epoch 18/200
#
# Epoch 00018: LearningRateScheduler reducing learning rate to 0.002.
# 3/3 [==============================] - 33s 11s/step - loss: 0.0141 - psnr: 18.5349
# Epoch 19/200
#
# Epoch 00019: LearningRateScheduler reducing learning rate to 0.002.
# 3/3 [==============================] - 33s 11s/step - loss: 0.0134 - psnr: 18.7483
# Epoch 20/200
#
# Epoch 00020: LearningRateScheduler reducing learning rate to 0.002.
# 3/3 [==============================] - 32s 11s/step - loss: 0.0117 - psnr: 19.3516
# Epoch 21/200
#
# Epoch 00021: LearningRateScheduler reducing learning rate to 0.002.
# 3/3 [==============================] - 33s 11s/step - loss: 0.0096 - psnr: 20.1669
# Epoch 22/200
#
# Epoch 00022: LearningRateScheduler reducing learning rate to 0.002.
# 3/3 [==============================] - 32s 11s/step - loss: 0.0097 - psnr: 20.1893
# Epoch 23/200
#
# Epoch 00023: LearningRateScheduler reducing learning rate to 0.002.
# 3/3 [==============================] - 33s 11s/step - loss: 0.0088 - psnr: 20.5337
# Epoch 24/200
#
# Epoch 00024: LearningRateScheduler reducing learning rate to 0.002.
# 3/3 [==============================] - 33s 11s/step - loss: 0.0078 - psnr: 21.1525
# Epoch 25/200
#
# Epoch 00025: LearningRateScheduler reducing learning rate to 0.002.
# 3/3 [==============================] - 33s 11s/step - loss: 0.0077 - psnr: 21.1746
# Epoch 26/200
#
# Epoch 00026: LearningRateScheduler reducing learning rate to 0.002.
# 3/3 [==============================] - 32s 11s/step - loss: 0.0072 - psnr: 21.4699
# Epoch 27/200
#
# Epoch 00027: LearningRateScheduler reducing learning rate to 0.002.
# 3/3 [==============================] - 33s 11s/step - loss: 0.0067 - psnr: 21.7844
# Epoch 28/200
#
# Epoch 00028: LearningRateScheduler reducing learning rate to 0.002.
# 3/3 [==============================] - 33s 11s/step - loss: 0.0059 - psnr: 22.2737
# Epoch 29/200
#
# Epoch 00029: LearningRateScheduler reducing learning rate to 0.002.
# 3/3 [==============================] - 33s 11s/step - loss: 0.0058 - psnr: 22.4003
# Epoch 30/200
#
# Epoch 00030: LearningRateScheduler reducing learning rate to 0.002.
# 3/3 [==============================] - 32s 10s/step - loss: 0.0057 - psnr: 22.4812
# Epoch 31/200
#
# Epoch 00031: LearningRateScheduler reducing learning rate to 0.002.
# 3/3 [==============================] - 33s 11s/step - loss: 0.0062 - psnr: 22.1015
# Epoch 32/200
#
# Epoch 00032: LearningRateScheduler reducing learning rate to 0.002.
# 3/3 [==============================] - 33s 11s/step - loss: 0.0057 - psnr: 22.4921
# Epoch 33/200
#
# Epoch 00033: LearningRateScheduler reducing learning rate to 0.002.
# 3/3 [==============================] - 33s 11s/step - loss: 0.0050 - psnr: 23.0817
# Epoch 34/200
#
# Epoch 00034: LearningRateScheduler reducing learning rate to 0.002.
# 3/3 [==============================] - 33s 11s/step - loss: 0.0050 - psnr: 23.0311
# Epoch 35/200
#
# Epoch 00035: LearningRateScheduler reducing learning rate to 0.002.
# 3/3 [==============================] - 32s 11s/step - loss: 0.0045 - psnr: 23.4944
# Epoch 36/200
#
# Epoch 00036: LearningRateScheduler reducing learning rate to 0.002.
# 3/3 [==============================] - 33s 11s/step - loss: 0.0045 - psnr: 23.4564
# Epoch 37/200
#
# Epoch 00037: LearningRateScheduler reducing learning rate to 0.002.
# 3/3 [==============================] - 33s 11s/step - loss: 0.0044 - psnr: 23.6148
# Epoch 38/200
#
# Epoch 00038: LearningRateScheduler reducing learning rate to 0.002.
# 3/3 [==============================] - 33s 11s/step - loss: 0.0044 - psnr: 23.5674
# Epoch 39/200
#
# Epoch 00039: LearningRateScheduler reducing learning rate to 0.002.
# 3/3 [==============================] - 33s 11s/step - loss: 0.0043 - psnr: 23.7111
# Epoch 40/200
#
# Epoch 00040: LearningRateScheduler reducing learning rate to 0.002.
# 3/3 [==============================] - 33s 11s/step - loss: 0.0039 - psnr: 24.0468
# Epoch 41/200
#
# Epoch 00041: LearningRateScheduler reducing learning rate to 0.002.
# 3/3 [==============================] - 33s 11s/step - loss: 0.0039 - psnr: 24.0662
# Epoch 42/200
#
# Epoch 00042: LearningRateScheduler reducing learning rate to 0.002.
# 3/3 [==============================] - 33s 11s/step - loss: 0.0038 - psnr: 24.1770
# Epoch 43/200
#
# Epoch 00043: LearningRateScheduler reducing learning rate to 0.002.
# 3/3 [==============================] - 32s 11s/step - loss: 0.0038 - psnr: 24.2437
# Epoch 44/200
#
# Epoch 00044: LearningRateScheduler reducing learning rate to 0.002.
# 3/3 [==============================] - 33s 11s/step - loss: 0.0035 - psnr: 24.5800
# Epoch 45/200
#
# Epoch 00045: LearningRateScheduler reducing learning rate to 0.002.
# 3/3 [==============================] - 32s 11s/step - loss: 0.0037 - psnr: 24.3447
# Epoch 46/200
#
# Epoch 00046: LearningRateScheduler reducing learning rate to 0.002.
# 3/3 [==============================] - 33s 11s/step - loss: 0.0034 - psnr: 24.6614
# Epoch 47/200
#
# Epoch 00047: LearningRateScheduler reducing learning rate to 0.002.
# 3/3 [==============================] - 32s 10s/step - loss: 0.0036 - psnr: 24.4434
# Epoch 48/200
#
# Epoch 00048: LearningRateScheduler reducing learning rate to 0.002.
# 3/3 [==============================] - 33s 10s/step - loss: 0.0036 - psnr: 24.4998
# Epoch 49/200
#
# Epoch 00049: LearningRateScheduler reducing learning rate to 0.002.
# 3/3 [==============================] - 33s 11s/step - loss: 0.0033 - psnr: 24.7915
# Epoch 50/200
#
# Epoch 00050: LearningRateScheduler reducing learning rate to 0.002.
# 3/3 [==============================] - 33s 11s/step - loss: 0.0036 - psnr: 24.4817
# Epoch 51/200
#
# Epoch 00051: LearningRateScheduler reducing learning rate to 0.002.
# 3/3 [==============================] - 33s 11s/step - loss: 0.0038 - psnr: 24.3760
# Epoch 52/200
#
# Epoch 00052: LearningRateScheduler reducing learning rate to 0.002.
# 3/3 [==============================] - 33s 11s/step - loss: 0.0032 - psnr: 25.0015
# Epoch 53/200
#
# Epoch 00053: LearningRateScheduler reducing learning rate to 0.002.
# 3/3 [==============================] - 33s 11s/step - loss: 0.0032 - psnr: 24.9777
# Epoch 54/200
#
# Epoch 00054: LearningRateScheduler reducing learning rate to 0.002.
# 3/3 [==============================] - 32s 11s/step - loss: 0.0033 - psnr: 24.8198
# Epoch 55/200
#
# Epoch 00055: LearningRateScheduler reducing learning rate to 0.002.
# 3/3 [==============================] - 33s 11s/step - loss: 0.0033 - psnr: 24.8911
# Epoch 56/200
#
# Epoch 00056: LearningRateScheduler reducing learning rate to 0.002.
# 3/3 [==============================] - 33s 11s/step - loss: 0.0034 - psnr: 24.7351
# Epoch 57/200
#
# Epoch 00057: LearningRateScheduler reducing learning rate to 0.002.
# 3/3 [==============================] - 33s 11s/step - loss: 0.0033 - psnr: 24.8689
# Epoch 58/200
#
# Epoch 00058: LearningRateScheduler reducing learning rate to 0.002.
# 3/3 [==============================] - 33s 11s/step - loss: 0.0033 - psnr: 24.8403
# Epoch 59/200
#
# Epoch 00059: LearningRateScheduler reducing learning rate to 0.002.
# 3/3 [==============================] - 33s 11s/step - loss: 0.0032 - psnr: 24.9830
# Epoch 60/200
#
# Epoch 00060: LearningRateScheduler reducing learning rate to 0.002.
# 3/3 [==============================] - 32s 11s/step - loss: 0.0029 - psnr: 25.4754
# Epoch 61/200
#
# Epoch 00061: LearningRateScheduler reducing learning rate to 0.002.
# 3/3 [==============================] - 33s 11s/step - loss: 0.0033 - psnr: 24.9551
# Epoch 62/200
#
# Epoch 00062: LearningRateScheduler reducing learning rate to 0.002.
# 3/3 [==============================] - 33s 11s/step - loss: 0.0029 - psnr: 25.4105
# Epoch 63/200
#
# Epoch 00063: LearningRateScheduler reducing learning rate to 0.002.
# 3/3 [==============================] - 33s 11s/step - loss: 0.0029 - psnr: 25.4534
# Epoch 64/200
#
# Epoch 00064: LearningRateScheduler reducing learning rate to 0.002.
# 3/3 [==============================] - 32s 11s/step - loss: 0.0030 - psnr: 25.2850
# Epoch 65/200
#
# Epoch 00065: LearningRateScheduler reducing learning rate to 0.002.
# 3/3 [==============================] - 33s 11s/step - loss: 0.0031 - psnr: 25.1490
# Epoch 66/200
#
# Epoch 00066: LearningRateScheduler reducing learning rate to 0.002.
# 3/3 [==============================] - 33s 11s/step - loss: 0.0028 - psnr: 25.5769
# Epoch 67/200
#
# Epoch 00067: LearningRateScheduler reducing learning rate to 0.002.
# 3/3 [==============================] - 33s 11s/step - loss: 0.0029 - psnr: 25.4025
# Epoch 68/200
#
# Epoch 00068: LearningRateScheduler reducing learning rate to 0.002.
# 3/3 [==============================] - 33s 11s/step - loss: 0.0032 - psnr: 25.0490
# Epoch 69/200
#
# Epoch 00069: LearningRateScheduler reducing learning rate to 0.002.
# 3/3 [==============================] - 33s 11s/step - loss: 0.0028 - psnr: 25.5676
# Epoch 70/200
#
# Epoch 00070: LearningRateScheduler reducing learning rate to 0.002.
# 3/3 [==============================] - 33s 11s/step - loss: 0.0028 - psnr: 25.4667
# Epoch 71/200
#
# Epoch 00071: LearningRateScheduler reducing learning rate to 0.002.
# 3/3 [==============================] - 33s 11s/step - loss: 0.0028 - psnr: 25.5147
# Epoch 72/200
#
# Epoch 00072: LearningRateScheduler reducing learning rate to 0.002.
# 3/3 [==============================] - 33s 11s/step - loss: 0.0030 - psnr: 25.2375
# Epoch 73/200
#
# Epoch 00073: LearningRateScheduler reducing learning rate to 0.002.
# 3/3 [==============================] - 33s 11s/step - loss: 0.0028 - psnr: 25.5309
# Epoch 74/200
#
# Epoch 00074: LearningRateScheduler reducing learning rate to 0.002.
# 3/3 [==============================] - 33s 11s/step - loss: 0.0027 - psnr: 25.7272
# Epoch 75/200
#
# Epoch 00075: LearningRateScheduler reducing learning rate to 0.002.
# 3/3 [==============================] - 33s 11s/step - loss: 0.0026 - psnr: 25.8301
# Epoch 76/200
#
# Epoch 00076: LearningRateScheduler reducing learning rate to 0.002.
# 3/3 [==============================] - 33s 11s/step - loss: 0.0027 - psnr: 25.7225
# Epoch 77/200
#
# Epoch 00077: LearningRateScheduler reducing learning rate to 0.002.
# 3/3 [==============================] - 33s 11s/step - loss: 0.0028 - psnr: 25.6072
# Epoch 78/200
#
# Epoch 00078: LearningRateScheduler reducing learning rate to 0.002.
# 3/3 [==============================] - 33s 11s/step - loss: 0.0026 - psnr: 25.8801
# Epoch 79/200
#
# Epoch 00079: LearningRateScheduler reducing learning rate to 0.002.
# 3/3 [==============================] - 32s 10s/step - loss: 0.0030 - psnr: 25.2429
# Epoch 80/200
#
# Epoch 00080: LearningRateScheduler reducing learning rate to 0.002.
# 3/3 [==============================] - 33s 11s/step - loss: 0.0034 - psnr: 24.7215
# Epoch 81/200
#
# Epoch 00081: LearningRateScheduler reducing learning rate to 0.002.
# 3/3 [==============================] - 33s 11s/step - loss: 0.0031 - psnr: 25.1995
# Epoch 82/200
#
# Epoch 00082: LearningRateScheduler reducing learning rate to 0.002.
# 3/3 [==============================] - 33s 11s/step - loss: 0.0029 - psnr: 25.3537
# Epoch 83/200
#
# Epoch 00083: LearningRateScheduler reducing learning rate to 0.002.
# 3/3 [==============================] - 32s 11s/step - loss: 0.0028 - psnr: 25.4820
# Epoch 84/200
#
# Epoch 00084: LearningRateScheduler reducing learning rate to 0.002.
# 3/3 [==============================] - 33s 11s/step - loss: 0.0027 - psnr: 25.6449
# Epoch 85/200
#
# Epoch 00085: LearningRateScheduler reducing learning rate to 0.002.
# 3/3 [==============================] - 33s 11s/step - loss: 0.0027 - psnr: 25.6692
# Epoch 86/200
#
# Epoch 00086: LearningRateScheduler reducing learning rate to 0.002.
# 3/3 [==============================] - 32s 10s/step - loss: 0.0027 - psnr: 25.8974
# Epoch 87/200
#
# Epoch 00087: LearningRateScheduler reducing learning rate to 0.002.
# 3/3 [==============================] - 33s 11s/step - loss: 0.0028 - psnr: 25.6325
# Epoch 88/200
#
# Epoch 00088: LearningRateScheduler reducing learning rate to 0.002.
# 3/3 [==============================] - 33s 11s/step - loss: 0.0024 - psnr: 26.3020
# Epoch 89/200
#
# Epoch 00089: LearningRateScheduler reducing learning rate to 0.002.
# 3/3 [==============================] - 33s 11s/step - loss: 0.0025 - psnr: 25.9493
# Epoch 90/200
#
# Epoch 00090: LearningRateScheduler reducing learning rate to 0.002.
# 3/3 [==============================] - 33s 11s/step - loss: 0.0024 - psnr: 26.1305
# Epoch 91/200
#
# Epoch 00091: LearningRateScheduler reducing learning rate to 0.002.
# 3/3 [==============================] - 33s 11s/step - loss: 0.0025 - psnr: 26.1634
# Epoch 92/200
#
# Epoch 00092: LearningRateScheduler reducing learning rate to 0.002.
# 3/3 [==============================] - 33s 11s/step - loss: 0.0026 - psnr: 25.9385
# Epoch 93/200
#
# Epoch 00093: LearningRateScheduler reducing learning rate to 0.002.
# 3/3 [==============================] - 33s 11s/step - loss: 0.0025 - psnr: 26.1404
# Epoch 94/200
#
# Epoch 00094: LearningRateScheduler reducing learning rate to 0.002.
# 3/3 [==============================] - 32s 11s/step - loss: 0.0026 - psnr: 25.8459
# Epoch 95/200
#
# Epoch 00095: LearningRateScheduler reducing learning rate to 0.002.
# 3/3 [==============================] - 33s 11s/step - loss: 0.0026 - psnr: 25.9262
# Epoch 96/200
#
# Epoch 00096: LearningRateScheduler reducing learning rate to 0.002.
# 3/3 [==============================] - 33s 11s/step - loss: 0.0025 - psnr: 26.0489
# Epoch 97/200
#
# Epoch 00097: LearningRateScheduler reducing learning rate to 0.002.
# 3/3 [==============================] - 33s 11s/step - loss: 0.0024 - psnr: 26.1082
# Epoch 98/200
#
# Epoch 00098: LearningRateScheduler reducing learning rate to 0.002.
# 3/3 [==============================] - 32s 11s/step - loss: 0.0025 - psnr: 26.0062
# Epoch 99/200
#
# Epoch 00099: LearningRateScheduler reducing learning rate to 0.002.
# 3/3 [==============================] - 33s 11s/step - loss: 0.0025 - psnr: 26.1117
# Epoch 100/200
#
# Epoch 00100: LearningRateScheduler reducing learning rate to 0.002.
# 3/3 [==============================] - 33s 11s/step - loss: 0.0026 - psnr: 26.0167
# Epoch 101/200
#
# Epoch 00101: LearningRateScheduler reducing learning rate to 0.002.
# 3/3 [==============================] - 33s 11s/step - loss: 0.0028 - psnr: 25.5925
# Epoch 102/200
#
# Epoch 00102: LearningRateScheduler reducing learning rate to 0.002.
# 3/3 [==============================] - 33s 11s/step - loss: 0.0033 - psnr: 24.8079
# Epoch 103/200
#
# Epoch 00103: LearningRateScheduler reducing learning rate to 0.002.
# 3/3 [==============================] - 33s 11s/step - loss: 0.0029 - psnr: 25.4759
# Epoch 104/200
#
# Epoch 00104: LearningRateScheduler reducing learning rate to 0.002.
# 3/3 [==============================] - 33s 11s/step - loss: 0.0032 - psnr: 25.0737
# Epoch 105/200
#
# Epoch 00105: LearningRateScheduler reducing learning rate to 0.002.
# 3/3 [==============================] - 33s 11s/step - loss: 0.0031 - psnr: 25.1446
# Epoch 106/200
#
# Epoch 00106: LearningRateScheduler reducing learning rate to 0.002.
# 3/3 [==============================] - 33s 11s/step - loss: 0.0028 - psnr: 25.5996
# Epoch 107/200
#
# Epoch 00107: LearningRateScheduler reducing learning rate to 0.002.
# 3/3 [==============================] - 32s 11s/step - loss: 0.0028 - psnr: 25.5919
# Epoch 108/200
#
# Epoch 00108: LearningRateScheduler reducing learning rate to 0.002.
# 3/3 [==============================] - 33s 11s/step - loss: 0.0024 - psnr: 26.3798
# Epoch 109/200
#
# Epoch 00109: LearningRateScheduler reducing learning rate to 0.002.
# 3/3 [==============================] - 33s 11s/step - loss: 0.0027 - psnr: 25.7514
# Epoch 110/200
#
# Epoch 00110: LearningRateScheduler reducing learning rate to 0.002.
# 3/3 [==============================] - 33s 11s/step - loss: 0.0027 - psnr: 25.7708
# Epoch 111/200
#
# Epoch 00111: LearningRateScheduler reducing learning rate to 0.002.
# 3/3 [==============================] - 33s 11s/step - loss: 0.0025 - psnr: 26.0649
# Epoch 112/200
#
# Epoch 00112: LearningRateScheduler reducing learning rate to 0.002.
# 3/3 [==============================] - 33s 11s/step - loss: 0.0027 - psnr: 25.8051
# Epoch 113/200
#
# Epoch 00113: LearningRateScheduler reducing learning rate to 0.002.
# 3/3 [==============================] - 33s 11s/step - loss: 0.0025 - psnr: 26.0048
# Epoch 114/200
#
# Epoch 00114: LearningRateScheduler reducing learning rate to 0.002.
# 3/3 [==============================] - 33s 11s/step - loss: 0.0023 - psnr: 26.3357
# Epoch 115/200
#
# Epoch 00115: LearningRateScheduler reducing learning rate to 0.002.
# 3/3 [==============================] - 33s 11s/step - loss: 0.0026 - psnr: 25.9208
# Epoch 116/200
#
# Epoch 00116: LearningRateScheduler reducing learning rate to 0.002.
# 3/3 [==============================] - 33s 11s/step - loss: 0.0026 - psnr: 25.9297
# Epoch 117/200
#
# Epoch 00117: LearningRateScheduler reducing learning rate to 0.002.
# 3/3 [==============================] - 33s 11s/step - loss: 0.0024 - psnr: 26.3058
# Epoch 118/200
#
# Epoch 00118: LearningRateScheduler reducing learning rate to 0.002.
# 3/3 [==============================] - 33s 11s/step - loss: 0.0024 - psnr: 26.2684
# Epoch 119/200
#
# Epoch 00119: LearningRateScheduler reducing learning rate to 0.002.
# 3/3 [==============================] - 33s 11s/step - loss: 0.0024 - psnr: 26.1742
# Epoch 120/200
#
# Epoch 00120: LearningRateScheduler reducing learning rate to 0.002.
# 3/3 [==============================] - 33s 11s/step - loss: 0.0025 - psnr: 26.1187
# Epoch 121/200
#
# Epoch 00121: LearningRateScheduler reducing learning rate to 0.002.
# 3/3 [==============================] - 33s 11s/step - loss: 0.0024 - psnr: 26.2871
# Epoch 122/200
#
# Epoch 00122: LearningRateScheduler reducing learning rate to 0.002.
# 3/3 [==============================] - 32s 11s/step - loss: 0.0021 - psnr: 26.8576
# Epoch 123/200
#
# Epoch 00123: LearningRateScheduler reducing learning rate to 0.002.
# 3/3 [==============================] - 33s 11s/step - loss: 0.0024 - psnr: 26.2233
# Epoch 124/200
#
# Epoch 00124: LearningRateScheduler reducing learning rate to 0.002.
# 3/3 [==============================] - 33s 11s/step - loss: 0.0023 - psnr: 26.4719
# Epoch 125/200
#
# Epoch 00125: LearningRateScheduler reducing learning rate to 0.002.
# 3/3 [==============================] - 33s 11s/step - loss: 0.0022 - psnr: 26.6083
# Epoch 126/200
#
# Epoch 00126: LearningRateScheduler reducing learning rate to 0.002.
# 3/3 [==============================] - 32s 11s/step - loss: 0.0022 - psnr: 26.5194
# Epoch 127/200
#
# Epoch 00127: LearningRateScheduler reducing learning rate to 0.002.
# 3/3 [==============================] - 33s 11s/step - loss: 0.0022 - psnr: 26.4868
# Epoch 128/200
#
# Epoch 00128: LearningRateScheduler reducing learning rate to 0.002.
# 3/3 [==============================] - 33s 11s/step - loss: 0.0022 - psnr: 26.6458
# Epoch 129/200
#
# Epoch 00129: LearningRateScheduler reducing learning rate to 0.002.
# 3/3 [==============================] - 33s 11s/step - loss: 0.0023 - psnr: 26.3561
# Epoch 130/200
#
# Epoch 00130: LearningRateScheduler reducing learning rate to 0.002.
# 3/3 [==============================] - 32s 11s/step - loss: 0.0022 - psnr: 26.6803
# Epoch 131/200
#
# Epoch 00131: LearningRateScheduler reducing learning rate to 0.002.
# 3/3 [==============================] - 33s 11s/step - loss: 0.0024 - psnr: 26.2114
# Epoch 132/200
#
# Epoch 00132: LearningRateScheduler reducing learning rate to 0.002.
# 3/3 [==============================] - 33s 11s/step - loss: 0.0023 - psnr: 26.5030
# Epoch 133/200
#
# Epoch 00133: LearningRateScheduler reducing learning rate to 0.002.
# 3/3 [==============================] - 33s 11s/step - loss: 0.0021 - psnr: 26.8683
# Epoch 134/200
#
# Epoch 00134: LearningRateScheduler reducing learning rate to 0.002.
# 3/3 [==============================] - 32s 11s/step - loss: 0.0023 - psnr: 26.3143
# Epoch 135/200
#
# Epoch 00135: LearningRateScheduler reducing learning rate to 0.002.
# 3/3 [==============================] - 33s 11s/step - loss: 0.0024 - psnr: 26.2084
# Epoch 136/200
#
# Epoch 00136: LearningRateScheduler reducing learning rate to 0.002.
# 3/3 [==============================] - 33s 11s/step - loss: 0.0024 - psnr: 26.2234
# Epoch 137/200
#
# Epoch 00137: LearningRateScheduler reducing learning rate to 0.002.
# 3/3 [==============================] - 32s 11s/step - loss: 0.0024 - psnr: 26.2088
# Epoch 138/200
#
# Epoch 00138: LearningRateScheduler reducing learning rate to 0.002.
# 3/3 [==============================] - 33s 11s/step - loss: 0.0024 - psnr: 26.3054
# Epoch 139/200
#
# Epoch 00139: LearningRateScheduler reducing learning rate to 0.002.
# 3/3 [==============================] - 33s 11s/step - loss: 0.0024 - psnr: 26.1890
# Epoch 140/200
#
# Epoch 00140: LearningRateScheduler reducing learning rate to 0.002.
# 3/3 [==============================] - 33s 11s/step - loss: 0.0023 - psnr: 26.4126
# Epoch 141/200
#
# Epoch 00141: LearningRateScheduler reducing learning rate to 0.002.
# 3/3 [==============================] - 32s 11s/step - loss: 0.0022 - psnr: 26.7008
# Epoch 142/200
#
# Epoch 00142: LearningRateScheduler reducing learning rate to 0.002.
# 3/3 [==============================] - 33s 11s/step - loss: 0.0022 - psnr: 26.5456
# Epoch 143/200
#
# Epoch 00143: LearningRateScheduler reducing learning rate to 0.002.
# 3/3 [==============================] - 33s 11s/step - loss: 0.0022 - psnr: 26.6090
# Epoch 144/200
#
# Epoch 00144: LearningRateScheduler reducing learning rate to 0.002.
# 3/3 [==============================] - 33s 11s/step - loss: 0.0023 - psnr: 26.4376
# Epoch 145/200
#
# Epoch 00145: LearningRateScheduler reducing learning rate to 0.002.
# 3/3 [==============================] - 32s 11s/step - loss: 0.0024 - psnr: 26.3207
# Epoch 146/200
#
# Epoch 00146: LearningRateScheduler reducing learning rate to 0.002.
# 3/3 [==============================] - 33s 11s/step - loss: 0.0021 - psnr: 26.7676
# Epoch 147/200
#
# Epoch 00147: LearningRateScheduler reducing learning rate to 0.002.
# 3/3 [==============================] - 33s 11s/step - loss: 0.0021 - psnr: 26.7231
# Epoch 148/200
#
# Epoch 00148: LearningRateScheduler reducing learning rate to 0.002.
# 3/3 [==============================] - 33s 11s/step - loss: 0.0022 - psnr: 26.6626
# Epoch 149/200
#
# Epoch 00149: LearningRateScheduler reducing learning rate to 0.002.
# 3/3 [==============================] - 33s 11s/step - loss: 0.0023 - psnr: 26.4217
# Epoch 150/200
#
# Epoch 00150: LearningRateScheduler reducing learning rate to 0.002.
# 3/3 [==============================] - 33s 10s/step - loss: 0.0023 - psnr: 26.4591
# Epoch 151/200
#
# Epoch 00151: LearningRateScheduler reducing learning rate to 0.002.
# 3/3 [==============================] - 33s 11s/step - loss: 0.0024 - psnr: 26.3918
# Epoch 152/200
#
# Epoch 00152: LearningRateScheduler reducing learning rate to 0.002.
# 3/3 [==============================] - 33s 11s/step - loss: 0.0021 - psnr: 26.7520
# Epoch 153/200
#
# Epoch 00153: LearningRateScheduler reducing learning rate to 0.002.
# 3/3 [==============================] - 33s 11s/step - loss: 0.0020 - psnr: 26.9857
# Epoch 154/200
#
# Epoch 00154: LearningRateScheduler reducing learning rate to 0.002.
# 3/3 [==============================] - 33s 11s/step - loss: 0.0021 - psnr: 26.8691
# Epoch 155/200
#
# Epoch 00155: LearningRateScheduler reducing learning rate to 0.002.
# 3/3 [==============================] - 33s 11s/step - loss: 0.0025 - psnr: 26.0956
# Epoch 156/200
#
# Epoch 00156: LearningRateScheduler reducing learning rate to 0.002.
# 3/3 [==============================] - 32s 11s/step - loss: 0.0022 - psnr: 26.5103
# Epoch 157/200
#
# Epoch 00157: LearningRateScheduler reducing learning rate to 0.002.
# 3/3 [==============================] - 33s 11s/step - loss: 0.0023 - psnr: 26.3209
# Epoch 158/200
#
# Epoch 00158: LearningRateScheduler reducing learning rate to 0.002.
# 3/3 [==============================] - 33s 11s/step - loss: 0.0022 - psnr: 26.6440
# Epoch 159/200
#
# Epoch 00159: LearningRateScheduler reducing learning rate to 0.002.
# 3/3 [==============================] - 33s 11s/step - loss: 0.0021 - psnr: 26.7373
# Epoch 160/200
#
# Epoch 00160: LearningRateScheduler reducing learning rate to 0.002.
# 3/3 [==============================] - 32s 11s/step - loss: 0.0020 - psnr: 27.1960
# Epoch 161/200
#
# Epoch 00161: LearningRateScheduler reducing learning rate to 0.002.
# 3/3 [==============================] - 33s 11s/step - loss: 0.0021 - psnr: 26.8738
# Epoch 162/200
#
# Epoch 00162: LearningRateScheduler reducing learning rate to 0.002.
# 3/3 [==============================] - 33s 11s/step - loss: 0.0021 - psnr: 26.8304
# Epoch 163/200
#
# Epoch 00163: LearningRateScheduler reducing learning rate to 0.002.
# 3/3 [==============================] - 33s 11s/step - loss: 0.0021 - psnr: 26.7876
# Epoch 164/200
#
# Epoch 00164: LearningRateScheduler reducing learning rate to 0.002.
# 3/3 [==============================] - 33s 11s/step - loss: 0.0023 - psnr: 26.4817
# Epoch 165/200
#
# Epoch 00165: LearningRateScheduler reducing learning rate to 0.002.
# 3/3 [==============================] - 33s 11s/step - loss: 0.0021 - psnr: 26.7508
# Epoch 166/200
#
# Epoch 00166: LearningRateScheduler reducing learning rate to 0.002.
# 3/3 [==============================] - 33s 11s/step - loss: 0.0023 - psnr: 26.4734
# Epoch 167/200
#
# Epoch 00167: LearningRateScheduler reducing learning rate to 0.002.
# 3/3 [==============================] - 33s 11s/step - loss: 0.0022 - psnr: 26.6890
# Epoch 168/200
#
# Epoch 00168: LearningRateScheduler reducing learning rate to 0.002.
# 3/3 [==============================] - 32s 11s/step - loss: 0.0019 - psnr: 27.1710
# Epoch 169/200
#
# Epoch 00169: LearningRateScheduler reducing learning rate to 0.002.
# 3/3 [==============================] - 33s 11s/step - loss: 0.0022 - psnr: 26.6154
# Epoch 170/200
#
# Epoch 00170: LearningRateScheduler reducing learning rate to 0.002.
# 3/3 [==============================] - 33s 11s/step - loss: 0.0022 - psnr: 26.6525
# Epoch 171/200
#
# Epoch 00171: LearningRateScheduler reducing learning rate to 0.002.
# 3/3 [==============================] - 33s 11s/step - loss: 0.0020 - psnr: 26.9673
# Epoch 172/200
#
# Epoch 00172: LearningRateScheduler reducing learning rate to 0.002.
# 3/3 [==============================] - 33s 11s/step - loss: 0.0021 - psnr: 26.7121
# Epoch 173/200
#
# Epoch 00173: LearningRateScheduler reducing learning rate to 0.002.
# 3/3 [==============================] - 32s 11s/step - loss: 0.0020 - psnr: 26.9173
# Epoch 174/200
#
# Epoch 00174: LearningRateScheduler reducing learning rate to 0.002.
# 3/3 [==============================] - 33s 11s/step - loss: 0.0021 - psnr: 26.8317
# Epoch 175/200
#
# Epoch 00175: LearningRateScheduler reducing learning rate to 0.002.
# 3/3 [==============================] - 33s 11s/step - loss: 0.0021 - psnr: 26.7527
# Epoch 176/200
#
# Epoch 00176: LearningRateScheduler reducing learning rate to 0.002.
# 3/3 [==============================] - 33s 11s/step - loss: 0.0021 - psnr: 26.8003
# Epoch 177/200
#
# Epoch 00177: LearningRateScheduler reducing learning rate to 0.002.
# 3/3 [==============================] - 32s 11s/step - loss: 0.0021 - psnr: 26.8257
# Epoch 178/200
#
# Epoch 00178: LearningRateScheduler reducing learning rate to 0.002.
# 3/3 [==============================] - 33s 11s/step - loss: 0.0020 - psnr: 26.9482
# Epoch 179/200
#
# Epoch 00179: LearningRateScheduler reducing learning rate to 0.002.
# 3/3 [==============================] - 33s 11s/step - loss: 0.0020 - psnr: 27.1415
# Epoch 180/200
#
# Epoch 00180: LearningRateScheduler reducing learning rate to 0.002.
# 3/3 [==============================] - 33s 11s/step - loss: 0.0020 - psnr: 27.0226
# Epoch 181/200
#
# Epoch 00181: LearningRateScheduler reducing learning rate to 0.002.
# 3/3 [==============================] - 32s 11s/step - loss: 0.0021 - psnr: 26.7970
# Epoch 182/200
#
# Epoch 00182: LearningRateScheduler reducing learning rate to 0.002.
# 3/3 [==============================] - 33s 11s/step - loss: 0.0021 - psnr: 26.7269
# Epoch 183/200
#
# Epoch 00183: LearningRateScheduler reducing learning rate to 0.002.
# 3/3 [==============================] - 33s 11s/step - loss: 0.0023 - psnr: 26.6058
# Epoch 184/200
#
# Epoch 00184: LearningRateScheduler reducing learning rate to 0.002.
# 3/3 [==============================] - 33s 11s/step - loss: 0.0020 - psnr: 27.1716
# Epoch 185/200
#
# Epoch 00185: LearningRateScheduler reducing learning rate to 0.002.
# 3/3 [==============================] - 33s 11s/step - loss: 0.0022 - psnr: 26.6789
# Epoch 186/200
#
# Epoch 00186: LearningRateScheduler reducing learning rate to 0.002.
# 3/3 [==============================] - 33s 11s/step - loss: 0.0021 - psnr: 26.9198
# Epoch 187/200
#
# Epoch 00187: LearningRateScheduler reducing learning rate to 0.002.
# 3/3 [==============================] - 33s 11s/step - loss: 0.0019 - psnr: 27.1324
# Epoch 188/200
#
# Epoch 00188: LearningRateScheduler reducing learning rate to 0.002.
# 3/3 [==============================] - 33s 11s/step - loss: 0.0019 - psnr: 27.4154
# Epoch 189/200
#
# Epoch 00189: LearningRateScheduler reducing learning rate to 0.002.
# 3/3 [==============================] - 33s 11s/step - loss: 0.0019 - psnr: 27.1397
# Epoch 190/200
#
# Epoch 00190: LearningRateScheduler reducing learning rate to 0.002.
# 3/3 [==============================] - 33s 11s/step - loss: 0.0022 - psnr: 26.6978
# Epoch 191/200
#
# Epoch 00191: LearningRateScheduler reducing learning rate to 0.002.
# 3/3 [==============================] - 33s 11s/step - loss: 0.0022 - psnr: 26.7060
# Epoch 192/200
#
# Epoch 00192: LearningRateScheduler reducing learning rate to 0.002.
# 3/3 [==============================] - 33s 11s/step - loss: 0.0019 - psnr: 27.3960
# Epoch 193/200
#
# Epoch 00193: LearningRateScheduler reducing learning rate to 0.002.
# 3/3 [==============================] - 33s 11s/step - loss: 0.0019 - psnr: 27.2169
# Epoch 194/200
#
# Epoch 00194: LearningRateScheduler reducing learning rate to 0.002.
# 3/3 [==============================] - 33s 11s/step - loss: 0.0019 - psnr: 27.2750
# Epoch 195/200
#
# Epoch 00195: LearningRateScheduler reducing learning rate to 0.002.
# 3/3 [==============================] - 33s 11s/step - loss: 0.0020 - psnr: 27.0486
# Epoch 196/200
#
# Epoch 00196: LearningRateScheduler reducing learning rate to 0.002.
# 3/3 [==============================] - 32s 11s/step - loss: 0.0021 - psnr: 26.8633
# Epoch 197/200
#
# Epoch 00197: LearningRateScheduler reducing learning rate to 0.002.
# 3/3 [==============================] - 33s 11s/step - loss: 0.0019 - psnr: 27.1366
# Epoch 198/200
#
# Epoch 00198: LearningRateScheduler reducing learning rate to 0.002.
# 3/3 [==============================] - 32s 10s/step - loss: 0.0020 - psnr: 27.0644
# Epoch 199/200
#
# Epoch 00199: LearningRateScheduler reducing learning rate to 0.002.
# 3/3 [==============================] - 33s 11s/step - loss: 0.0019 - psnr: 27.2398
# Epoch 200/200
#
# Epoch 00200: LearningRateScheduler reducing learning rate to 0.002.
# 3/3 [==============================] - 32s 11s/step - loss: 0.0019 - psnr: 27.3647

# %%
results = model.predict(image,verbose=1)
# Out:
# 3/3 [==============================] - 8s 2s/step

# %%
n = 0

plt.figure(figsize=(14, 7))

ax = plt.subplot(1, 3, 3)
plt.imshow(np.squeeze(results[n]))

ax = plt.subplot(1, 3, 2)
plt.imshow(np.squeeze(image[n]))

ax = plt.subplot(1, 3, 1)
plt.imshow(np.squeeze(label[n]))
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
print(psnr(np.squeeze(image[0]),np.squeeze(results[0])))
# Out:
# tf.Tensor(26.06645398655284, shape=(), dtype=float64)
